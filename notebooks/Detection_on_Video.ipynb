# %%
from ultralytics import YOLO

model = YOLO("../notebooks/runs/detect/train/weights/best.pt")

# %%
results = model.predict(
    source="../videos/cricket_ball_demo.mp4",
    conf=0.15,
    save=True,
    stream=True
)
