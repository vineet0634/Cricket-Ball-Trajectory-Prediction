# %%
import cv2
import os

# %%
os.listdir("videos")
# Out:
# ['cricket_ball_demo.mp4']

# %%
cap = cv2.VideoCapture("videos/cricket_ball_demo.mp4")
print(cap.isOpened())
# Out:
# True

# %%
video_path = "videos/cricket_ball_demo.mp4"
output_folder = "frames"

# %%
os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)

frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imwrite(f"{output_folder}/frame_{frame_count}.jpg", frame)
    frame_count += 1

cap.release()

print("Total frames:", frame_count)
# Out:
# Total frames: 338

# %%
import matplotlib.pyplot as plt

img = cv2.imread("frames/frame_50.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(359.5), np.float64(639.5), np.float64(-0.5))
