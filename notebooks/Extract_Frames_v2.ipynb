# %%
import cv2
import os

video_path = "../videos/umpire_view.mp4"
output_folder = "../frames_v2/umpire_frames"

os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)

frame_count = 0
saved_count = 0

FRAME_SKIP = 3       # save every 3rd frame

while True:
    ret, frame = cap.read()

    if not ret:
        break

    if frame_count % FRAME_SKIP == 0:

        filename = os.path.join(
            output_folder,
            f"frame_{saved_count:03d}.jpg"
        )

        cv2.imwrite(filename, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print("Total frames saved:", saved_count)
# Out:
# Total frames saved: 104

# %%
video_path = "../videos/side_view.mp4"
output_folder = "../frames_v2/side_frames"

os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)

frame_count = 0
saved_count = 0

FRAME_SKIP = 3       # save every 3rd frame

while True:
    ret, frame = cap.read()

    if not ret:
        break

    if frame_count % FRAME_SKIP == 0:

        filename = os.path.join(
            output_folder,
            f"frame_{saved_count:03d}.jpg"
        )

        cv2.imwrite(filename, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print("Total frames saved:", saved_count)
# Out:
# Total frames saved: 102
